# %% [markdown]
# <a href="https://colab.research.google.com/github/mit1208/Tutorials/blob/main/Pandas%27s_Tutorial_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
import urllib.request as ur
import json
import pandas as pd
import numpy as np

# %% [markdown]
# # Extract Data from API

# %%
url = 'https://data.yorkopendata.org/api/3/action/datastore_search?resource_id=58f995c1-da44-418f-9977-5ac41c63ccba'  
fileobj = ur.urlopen(url)
#print (fileobj.read())

# %%
data = fileobj.read()
json_data = json.loads(data)

# %% [markdown]
# # Load Data from Response

# %%
json_data_records = json_data['result']['records']
payment_df = pd.DataFrame.from_records(json_data_records)

# %%
payment_df.head()
# Out:
#    _id     Organisation_Name                   Directorate  \
# 0    1  City of York Council  Children Educn & Communities
# 1    2  City of York Council  Children Educn & Communities
# 2    3  City of York Council  Children Educn & Communities
# 3    4  City of York Council  Children Educn & Communities
# 4    5  City of York Council  Children Educn & Communities
#
#                       Department                    Service_Plan  \
# 0  Childrens Specialist Services  Childrens Social Work Services
# 1  Childrens Specialist Services  Childrens Social Work Services
# 2  Childrens Specialist Services  Childrens Social Work Services
# 3  Childrens Specialist Services  Childrens Social Work Services
# 4  Childrens Specialist Services  Childrens Social Work Services
#
#                   Creditor_Name         Payment_Date  Card_Transaction  \
# 0           Dr Susan Cooper Ltd  2021-06-04T00:00:00  202122CR00000001
# 1                        Ofsted  2021-06-04T00:00:00  202122CR00000002
# 2  Crombie Wilkinson Solicitors  2021-06-04T00:00:00  202122CR00000003
# 3  Crombie Wilkinson Solicitors  2021-06-04T00:00:00  202122CR00000004
# 4         Miss Rebecca Musgrove  2021-06-04T00:00:00  202122CR00000005
#
#   Transaction_No  Net_Amount Irrecoverable_VAT       Subjective_Group  \
# 0                    1872.00                    Supplies And Services
# 1                    2059.00                    Supplies And Services
# 2                     105.15                    Supplies And Services
# 3                     215.00                    Supplies And Services
# 4                     350.00                    Supplies And Services
#
#         Subjective_Subgroup    Subjective_Detail
# 0                  Services         Medical Fees
# 1  Grants and Subscriptions        Subscriptions
# 2                  Services  External Solicitors
# 3                  Services  External Solicitors
# 4                  Services      Barristers Fees

# %%
payment_df['Department'].unique()
# Out:
# array(['Childrens Specialist Services', 'Transp Highways & Environment',
#        'Transport Highways and Environ', 'Housing & Community Safety',
#        'Education and Skills', 'Adult Social Care',
#        'Adult Services Commissioning', 'Communities and Equalities',
#        'Customer Experience & Digital', 'Housing & Public Protection',
#        'Office of the Director CEC', 'Director CCS Direct Reports',
#        'Legal & Governance', 'Commercial Property'], dtype=object)

# %% [markdown]
# # Find All Columns in which NAN value/es is/are present

# %%
#replace empty string or white space to NAN - preprocessing
payment_df.replace(r'^\s*$', np.nan, regex=True, inplace = True)

# %%
payment_df.columns[payment_df.isnull().any()]
# Out:
# Index(['Transaction_No', 'Irrecoverable_VAT'], dtype='object')

# %% [markdown]
# # Create New column based on Existing Colum - Encoding
#
# Implementaion Logic to club Departments using below logic
#
# *   'Transp Highways & Environment', 'Transport Highways and Environ' - **Transportation**
# *  'Housing & Community Safety','Housing & Public Protection' - **Housing**
#
# *   'Office of the Director CEC', 'Director CCS Direct Reports' - **Director**
# *   'Adult Social Care',
#        'Adult Services Commissioning' - **Adult**
# *   'Communities and Equalities',
#        'Customer Experience & Digital',
#        'Legal & Governance', 'Commercial Property' - **Communities**
# *   'Childrens Specialist Services', 'Education and Skills' - **Education**

# %%
education_substring = ['Childrens Specialist Services', 'Education and Skills']
payment_df['department_encoded']  = np.where(
              payment_df['Department'].str.contains('Transp'),
              'Transportation',
              np.where(
                  payment_df['Department'].str.contains('Housing'),
                  'Housing',
                  np.where(
                    payment_df['Department'].str.contains('Director'),
                    'Director',
                    np.where(
                      payment_df['Department'].str.contains('Adult'),
                      'Adult',
                      np.where(
                              payment_df['Department'].str.contains('|'.join(education_substring)),
                              'Education',
                              'Communities'
                      )
                    )
                  )
                )
              )

# %% [markdown]
# # Get Year, Month and Day information from Date Column

# %%
#convert payment date to DATETIME type
payment_df['Payment_Date'] = pd.to_datetime(payment_df['Payment_Date'])

# %%
#Extract Year, Month, Day
payment_df['Year'] = payment_df['Payment_Date'].dt.year
payment_df['Month'] = payment_df['Payment_Date'].dt.month
payment_df['Day'] = payment_df['Payment_Date'].dt.day

# %% [markdown]
# # Let's Set Fiscal Year from March
#
# *   Quarter-1 : March, April, May
#
# *   Quarter-2 : June, July, August
# *   Quarter-3 : September, October, November
#
#
# *   Quarter-4 : December, January, February
#
#
# You Can set any starting month for Fiscal Year, just replace "March" with desired month

# %%
payment_fiscal_info = pd.PeriodIndex(payment_df['Payment_Date'], freq='Q-MAR')

# %%
payment_fiscal_info.strftime('Q%q')
# Out:
# Index(['Q1', 'Q1', 'Q1', 'Q1', 'Q1', 'Q1', 'Q1', 'Q1', 'Q1', 'Q1', 'Q1', 'Q1',
#        'Q1', 'Q1', 'Q1', 'Q1', 'Q1', 'Q1', 'Q2', 'Q2', 'Q1', 'Q1', 'Q1', 'Q1',
#        'Q1', 'Q1', 'Q1', 'Q1', 'Q1', 'Q1', 'Q1', 'Q1', 'Q1', 'Q1', 'Q1', 'Q1',
#        'Q1', 'Q3', 'Q1', 'Q1', 'Q2', 'Q1', 'Q1', 'Q2', 'Q1', 'Q1', 'Q1', 'Q1',
#        'Q1', 'Q1', 'Q1', 'Q1', 'Q1', 'Q2', 'Q1', 'Q1', 'Q1', 'Q2', 'Q1', 'Q2',
#        'Q2', 'Q2', 'Q2', 'Q2', 'Q2', 'Q2', 'Q2', 'Q2', 'Q2', 'Q2', 'Q2', 'Q2',
#        'Q2', 'Q2', 'Q2', 'Q2', 'Q2', 'Q2', 'Q2', 'Q2', 'Q2', 'Q2', 'Q2', 'Q2',
#        'Q2', 'Q2', 'Q2', 'Q2', 'Q2', 'Q2', 'Q2', 'Q2', 'Q2', 'Q2', 'Q2', 'Q2',
#        'Q2', 'Q2', 'Q2', 'Q1'],
#       dtype='object', name='Payment_Date')

# %%
payment_df['fiscal_year'] = payment_fiscal_info.year
payment_df['fiscal_quarter'] = payment_fiscal_info.quarter

# %% [markdown]
# # Create a new column using exsiting column data.
#
# Use 'Card_Transaction' column and extract number from it and create new column call 'Card_Transaction_num'
#
# There are multiple ways to do it. Here I have showed two methods.
#
# 1. Apply function - can be use to create new column using mutiple columns with complex logics
# 2. numpy vectorization method - This is very fast but hard to implement every time.

# %% [markdown]
# ```
# # First Way
# ```

# %%
# %timeit payment_df['Card_Transaction_num'] = payment_df.apply(lambda x: x['Card_Transaction'].split("CR")[-1],axis=1)
# Out:
# 100 loops, best of 5: 2.07 ms per loop

# %% [markdown]
# ```
# # Second Method
# ```

# %%
def get_acc_num(card_trans):
  return card_trans.split("CR")[-1]
np_func_get_accno = np.vectorize(get_acc_num)
# %timeit payment_df['Card_Transaction_num'] = np_func_get_accno(payment_df['Card_Transaction'])
# Out:
# 1000 loops, best of 5: 244 µs per loop

# %% [markdown]
# # In-Line Pandas Operations

# %% [markdown]
# Fetch Columns which have Numeric Values

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
payment_df.select_dtypes(include=numerics)
# Out:
#     _id  Net_Amount  Year  Month  Day  fiscal_year  fiscal_quarter
# 0     1     1872.00  2021      6    4         2021               1
# 1     2     2059.00  2021      6    4         2021               1
# 2     3      105.15  2021      6    4         2021               1
# 3     4      215.00  2021      6    4         2021               1
# 4     5      350.00  2021      6    4         2021               1
# ..  ...         ...   ...    ...  ...          ...             ...
# 95  108     3545.98  2021      7    4         2021               2
# 96   96     -399.00  2021      7    4         2021               2
# 97   97     -327.00  2021      7    4         2021               2
# 98   98     -399.00  2021      7    4         2021               2
# 99   99      829.09  2021      4   16         2021               1
#
# [100 rows x 7 columns]

# %% [markdown]
# ## Fetch rows based on Condition on Columns

# %%
payment_df[payment_df['Subjective_Group']=='Transport Costs']
# Out:
#     _id     Organisation_Name                   Directorate  \
# 18   19  City of York Council  Children Educn & Communities
# 19   20  City of York Council  Children Educn & Communities
#
#               Department                    Service_Plan  \
# 18  Education and Skills  School Services & Business Sup
# 19  Education and Skills  School Services & Business Sup
#
#                                     Creditor_Name Payment_Date  \
# 18  Streamline Taxis (York) Ltd - Large Contracts   2021-09-04
# 19  Streamline Taxis (York) Ltd - Large Contracts   2021-09-04
#
#     Card_Transaction Transaction_No  Net_Amount  ... Subjective_Group  \
# 18  202122CR00000019            NaN   106232.07  ...  Transport Costs
# 19  202122CR00000020            NaN   122423.57  ...  Transport Costs
#
#    Subjective_Subgroup Subjective_Detail department_encoded  Year  Month  Day  \
# 18      Transport Hire      Vehicle Hire          Education  2021      9    4
# 19      Transport Hire      Vehicle Hire          Education  2021      9    4
#
#     fiscal_year  fiscal_quarter  Card_Transaction_num
# 18         2021               2              00000019
# 19         2021               2              00000020
#
# [2 rows x 21 columns]

# %%
#Fetch specific Card_Transaction based on List values
card_trans_list = ['202122CR00000001','202122CR00000090']
payment_df[payment_df['Card_Transaction'].isin(card_trans_list)]
# Out:
#     _id     Organisation_Name                     Directorate  \
# 0     1  City of York Council    Children Educn & Communities
# 89   90  City of York Council  Health Housing & Adult So Care
#
#                        Department                    Service_Plan  \
# 0   Childrens Specialist Services  Childrens Social Work Services
# 89              Adult Social Care              Adult Safeguarding
#
#           Creditor_Name Payment_Date  Card_Transaction Transaction_No  \
# 0   Dr Susan Cooper Ltd   2021-06-04  202122CR00000001            NaN
# 89      United Response   2021-07-04  202122CR00000090            NaN
#
#     Net_Amount  ...       Subjective_Group Subjective_Subgroup  \
# 0      1872.00  ...  Supplies And Services            Services
# 89      749.76  ...  Supplies And Services            Services
#
#    Subjective_Detail department_encoded  Year  Month  Day  fiscal_year  \
# 0       Medical Fees          Education  2021      6    4         2021
# 89       Day Support              Adult  2021      7    4         2021
#
#     fiscal_quarter  Card_Transaction_num
# 0                1              00000001
# 89               2              00000090
#
# [2 rows x 21 columns]

# %%
payment_df[(payment_df['Subjective_Group']=='Supplies And Services') & (payment_df['Subjective_Subgroup']=='Equip, Furn, Mat') & (payment_df['Month']==7)]
# Out:
#     _id     Organisation_Name                     Directorate  \
# 40   41  City of York Council    Children Educn & Communities
# 43   44  City of York Council    Children Educn & Communities
# 96   96  City of York Council  Health Housing & Adult So Care
# 97   97  City of York Council  Health Housing & Adult So Care
# 98   98  City of York Council  Health Housing & Adult So Care
#
#                     Department               Service_Plan     Creditor_Name  \
# 40        Education and Skills  Special Educational Needs  No Isolation Ltd
# 43        Education and Skills  Special Educational Needs  No Isolation Ltd
# 96  Housing & Community Safety       Building Maintenance    Jewson Limited
# 97  Housing & Community Safety       Building Maintenance    Jewson Limited
# 98  Housing & Community Safety       Building Maintenance    Jewson Limited
#
#    Payment_Date  Card_Transaction Transaction_No  Net_Amount  ...  \
# 40   2021-07-04  202122CR00000041            NaN      -679.0  ...
# 43   2021-07-04  202122CR00000044            NaN       679.0  ...
# 96   2021-07-04  202122CR00000096            NaN      -399.0  ...
# 97   2021-07-04  202122CR00000097            NaN      -327.0  ...
# 98   2021-07-04  202122CR00000098            NaN      -399.0  ...
#
#          Subjective_Group Subjective_Subgroup  \
# 40  Supplies And Services    Equip, Furn, Mat
# 43  Supplies And Services    Equip, Furn, Mat
# 96  Supplies And Services    Equip, Furn, Mat
# 97  Supplies And Services    Equip, Furn, Mat
# 98  Supplies And Services    Equip, Furn, Mat
#
#                            Subjective_Detail department_encoded  Year  Month  \
# 40                     Operational Equipment          Education  2021      7
# 43                     Operational Equipment          Education  2021      7
# 96  Operational Materials (Rechargeable Wks)            Housing  2021      7
# 97  Operational Materials (Rechargeable Wks)            Housing  2021      7
# 98  Operational Materials (Rechargeable Wks)            Housing  2021      7
#
#     Day  fiscal_year  fiscal_quarter  Card_Transaction_num
# 40    4         2021               2              00000041
# 43    4         2021               2              00000044
# 96    4         2021               2              00000096
# 97    4         2021               2              00000097
# 98    4         2021               2              00000098
#
# [5 rows x 21 columns]

# %%
#get values of specific column based on condition on other column
payment_df.loc[payment_df['Creditor_Name'] == 'Jewson Limited', 'Net_Amount']
# Out:
#     _id     Organisation_Name                     Directorate  \
# 96   96  City of York Council  Health Housing & Adult So Care
# 97   97  City of York Council  Health Housing & Adult So Care
# 98   98  City of York Council  Health Housing & Adult So Care
# 99   99  City of York Council  Health Housing & Adult So Care
#
#                     Department          Service_Plan   Creditor_Name  \
# 96  Housing & Community Safety  Building Maintenance  Jewson Limited
# 97  Housing & Community Safety  Building Maintenance  Jewson Limited
# 98  Housing & Community Safety  Building Maintenance  Jewson Limited
# 99  Housing & Community Safety  Building Maintenance  Jewson Limited
#
#    Payment_Date  Card_Transaction Transaction_No  Net_Amount  ...  \
# 96   2021-07-04  202122CR00000096            NaN     -399.00  ...
# 97   2021-07-04  202122CR00000097            NaN     -327.00  ...
# 98   2021-07-04  202122CR00000098            NaN     -399.00  ...
# 99   2021-04-16  202122CR00000099            NaN      829.09  ...
#
#          Subjective_Group Subjective_Subgroup  \
# 96  Supplies And Services    Equip, Furn, Mat
# 97  Supplies And Services    Equip, Furn, Mat
# 98  Supplies And Services    Equip, Furn, Mat
# 99  Supplies And Services    Equip, Furn, Mat
#
#                            Subjective_Detail department_encoded  Year  Month  \
# 96  Operational Materials (Rechargeable Wks)            Housing  2021      7
# 97  Operational Materials (Rechargeable Wks)            Housing  2021      7
# 98  Operational Materials (Rechargeable Wks)            Housing  2021      7
# 99  Operational Materials (Rechargeable Wks)            Housing  2021      4
#
#     Day  fiscal_year  fiscal_quarter  Card_Transaction_num
# 96    4         2021               2              00000096
# 97    4         2021               2              00000097
# 98    4         2021               2              00000098
# 99   16         2021               1              00000099
#
# [4 rows x 21 columns]

# %% [markdown]
# # Operations on Columns

# %%
#get values of specific column based on condition on other column
payment_df.loc[payment_df['Creditor_Name'] == 'Jewson Limited', 'Net_Amount']
# Out:
# 96   -399.00
# 97   -327.00
# 98   -399.00
# 99    829.09
# Name: Net_Amount, dtype: float64

# %%
#Get first value from the returned values
payment_df.loc[payment_df['Creditor_Name'] == 'Jewson Limited', 'Net_Amount'].iloc[0]
# Out:
# -399.0

# %%
#Another way to get values of specific column based on condition on other column
payment_df.loc[payment_df['Creditor_Name'] == 'Jewson Limited']['Net_Amount']
# Out:
# 96   -399.00
# 97   -327.00
# 98   -399.00
# 99    829.09
# Name: Net_Amount, dtype: float64

# %%
#convert into Array using "values"
payment_df.loc[payment_df['Creditor_Name'] == 'Jewson Limited', 'Net_Amount'].values
# Out:
# array([-399.  , -327.  , -399.  ,  829.09])
